# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %%
df = pd.read_csv("../references/ad_tune_Apr28_1504_47118830.log.csv")

# %%
cols = ['avg_ep_avg_reward', 'config/batch_size',
       'config/eps_decay', 'config/eps_end', 'config/eps_start',
       'config/gamma', 'config/learning_rate', 'config/num_layers',
       'config/num_neurons', 'config/replay_mem', 'config/tau',]
df = df[cols]

# %%
df_sort = df.sort_values(by=['avg_ep_avg_reward'],ascending=False)

# %%
df_top = df_sort[:100]

# %%
df_sort["config/gamma"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
# FIX don't normalize all cols, plot only high reward?
# df_normal=(df_sort-df_sort.min())/(df_sort.max()-df_sort.min())
# fig = px.line(df_normal, y="avg_ep_avg_reward", x=cols ,markers=True)
# fig.show()

# Don't see any peaks of high reward, but maybe that's because we are looking at 2D plots. 
# Maybe in 10D, these values are the peaks. IDK. How do you evaluate HPO anyways?

# %%
i = 2
fig = px.line(df_sort.sort_values(by=cols[i]), y="avg_ep_avg_reward", x=cols[i],markers=True)
fig.show()
# Out:
# <div>                            <div id="a8cb4d18-9351-4f5d-aea7-69c05475a4dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8cb4d18-9351-4f5d-aea7-69c05475a4dd")) {                    Plotly.newPlot(                        "a8cb4d18-9351-4f5d-aea7-69c05475a4dd",                        [{"hovertemplate":"config/num_neurons=%{x}<br>avg_ep_avg_reward=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines","name":"","showlegend":false,"x":[16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,16,1
# ...
